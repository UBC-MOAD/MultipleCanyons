# %% [markdown]
# ## South Vancouver Island bathymetry
#
# * Barkley, Nitnat bathymetries
# * Distance between canyons

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.io as sio
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# SouthVIgrid.mat gives lat shape 1474, lon shape 890 and dpth shape (890,1474)

# %%
def get_topo():
     topo=sio.loadmat('/ocean/kramosmu/FalkorData/SouthVIgrid.mat')

     tDat = {'lon' : [], 'lat' : [], 'dpth' : []}

     tDat['lon'] = np.squeeze(np.array(topo['SouthVIgrid']['lon'][0][0]))
     tDat['lat'] = np.squeeze(np.array(topo['SouthVIgrid']['lat'][0][0]))
     tDat['dpth'] = np.squeeze(np.array(topo['SouthVIgrid']['depth'][0][0]))

     return tDat

# %%
tDat = get_topo()

plt.rcParams['contour.negative_linestyle'] = 'solid'

fig, ax1 = plt.subplots(1, 1, figsize=(8,6))

ax1.pcolor(tDat['lon'],tDat['lat'],tDat['dpth'], cmap ='gist_earth' )

CS = plt.contour(tDat['lon'],tDat['lat'],tDat['dpth'],[-150,-300,-500,-1000, -2000,0],
                 colors='k',linewidths=[1.5,1.5,1.5,1.5,1.5,2.25] )
plt.clabel(CS, inline=1, fontsize=10,fmt='%1.0f')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-daa2e419d370> in <module>()
#       7 ax1.pcolor(tDat['lon'],tDat['lat'],tDat['dpth'], cmap ='gist_earth' )
#       8
# ----> 9 CS = plt.contour(tDat['lon'],tDat['lat'],tDat['dpth'],[-150,-300,-500,-1000, -2000,0],colors='k',linewidths=[1.5,1.5,1.5,1.5,1.5,2.25] )
#      10 plt.clabel(CS, inline=1, fontsize=10,fmt='%1.0f')
#
# /home/kramosmu/anaconda3/lib/python3.5/site-packages/matplotlib/pyplot.py in contour(*args, **kwargs)
#    2771         ax.hold(hold)
#    2772     try:
# -> 2773         ret = ax.contour(*args, **kwargs)
#    2774     finally:
#    2775         ax.hold(washold)
#
# /home/kramosmu/anaconda3/lib/python3.5/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1817                     warnings.warn(msg % (label_namer, func.__name__),
#    1818                                   RuntimeWarning, stacklevel=2)
# -> 1819             return func(ax, *args, **kwargs)
#    1820         pre_doc = inner.__doc__
#    1821         if pre_doc is None:
#
# /home/kramosmu/anaconda3/lib/python3.5/site-packages/matplotlib/axes/_axes.py in contour(self, *args, **kwargs)
#    5617             self.cla()
#    5618         kwargs['filled'] = False
# -> 5619         return mcontour.QuadContourSet(self, *args, **kwargs)
#    5620     contour.__doc__ = mcontour.QuadContourSet.contour_doc
#    5621
#
# /home/kramosmu/anaconda3/lib/python3.5/site-packages/matplotlib/contour.py in __init__(self, ax, *args, **kwargs)
#    1422         are described in QuadContourSet.contour_doc.
#    1423         """
# -> 1424         ContourSet.__init__(self, ax, *args, **kwargs)
#    1425
#    1426     def _process_args(self, *args, **kwargs):
#
# /home/kramosmu/anaconda3/lib/python3.5/site-packages/matplotlib/contour.py in __init__(self, ax, *args, **kwargs)
#     861         self._transform = kwargs.get('transform', None)
#     862
# --> 863         self._process_args(*args, **kwargs)
#     864         self._process_levels()
#     865
#
# /home/kramosmu/anaconda3/lib/python3.5/site-packages/matplotlib/contour.py in _process_args(self, *args, **kwargs)
#    1443                 self._corner_mask = mpl.rcParams['contour.corner_mask']
#    1444
# -> 1445             x, y, z = self._contour_args(args, kwargs)
#    1446
#    1447             _mask = ma.getmask(z)
#
# /home/kramosmu/anaconda3/lib/python3.5/site-packages/matplotlib/contour.py in _contour_args(self, args, kwargs)
#    1538             warnings.warn('Log scale: values of z <= 0 have been masked')
#    1539             self.zmin = float(z.min())
# -> 1540         self._contour_level_args(z, args)
#    1541         return (x, y, z)
#    1542
#
# /home/kramosmu/anaconda3/lib/python3.5/site-packages/matplotlib/contour.py in _contour_level_args(self, z, args)
#    1187                 warnings.warn("Contour levels are not increasing")
#    1188             else:
# -> 1189                 raise ValueError("Contour levels must be increasing")
#    1190
#    1191     def _process_levels(self):
#
# ValueError: Contour levels must be increasing

# %%
fig46=plt.figure(figsize=(10,8))

plt.pcolor(tDat['lon'][450:900],tDat['lat'][50:500],tDat['dpth'][50:500,450:900],cmap='gist_earth')

CS = plt.contour(tDat['lon'][450:900],tDat['lat'][50:500],tDat['dpth'][50:500,450:900],[-100,-150,-200,-300,-400,-500,-800,-1000, -2000,0],colors='k',linewidths=[2])
plt.clabel(CS, inline=1, fontsize=10,fmt='%1.0f')

plt.plot(-125.9,48.4,'r*',markersize=17)
plt.plot(-125.67,48.24,'r*',markersize=17)

plt.plot(-125.86,48.32,'c*',markersize=17)
plt.plot(-125.8,48.26,'c*',markersize=17)

# %% [markdown]
# Distance between the two heads (red stars on map)  :
#
#    **25 km** rounded to the nearest whole unit - form http://www.nhc.noaa.gov/gccalc.shtml
#
#    **24.62 km** using Haversine formula http://andrew.hedges.name/experiments/haversine/
#
# Distance between the end of one canyon and the beginning of the other (200 m isobath, cyan stars)  :
#
#    **8.016 km** using Haversine formula http://andrew.hedges.name/experiments/haversine/
